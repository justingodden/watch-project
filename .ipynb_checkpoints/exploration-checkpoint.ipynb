# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline
plt.style.use('seaborn')
mpl.rcParams['figure.figsize'] = (18, 8)
plt.rc('axes', titlesize=22) 
plt.rc('figure', titlesize=22)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('axes', labelsize=14)

# %%
df = pd.read_csv('wf_df_raw.csv').drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    id                brand             series            model    price  \
# 0   0                  IWC     Pilots Classic         IW326901   4250.0
# 1   1                  IWC      Pilots Chrono         IW370623   3250.0
# 2   2  Vacheron Constantin           Overseas  47450/000R-9404  23950.0
# 3   3                  IWC          Pilots 36         IW324009   2850.0
# 4   4     Jaeger-LeCoultre  Reverso Classique          2538420   4950.0
#
#     Year  Box Papers Manufacturer warranty Watchfinder warranty  ...  \
# 0   2020  Yes    Yes  10  Months remaining          24 months*   ...
# 1   2006  Yes    Yes                   NaN          24 months*   ...
# 2   2017  Yes    Yes                   NaN          24 months*   ...
# 3   2017  Yes    Yes                   NaN          24 months*   ...
# 4   2017  Yes    Yes                   NaN          24 months*   ...
#
#   Returns policy Product code   Movement  Case size    Case material  \
# 0       14 days*       176824  Automatic      41 MM  Ceramic - Black
# 1       14 days*       166397  Automatic      39 MM            Steel
# 2       14 days*       176610  Automatic      42 MM        Rose Gold
# 3       14 days*       177267  Automatic      36 MM            Steel
# 4       14 days*       177142  Automatic    24.4 MM            Steel
#
#     Bracelet material      Dial type Water resistance      Location img_name
# 0     Fabric - Black    Black Arabic        60 metres  Call to view    0.jpg
# 1  Crocodile - Brown   Silver Arabic        60 metres  Call to view    1.jpg
# 2  Alligator - Brown    Silver Baton       150 metres  Call to view    2.jpg
# 3  Alligator - Brown    Brown Arabic        60 metres  Call to view    3.jpg
# 4   Crocodile - Black  Silver Arabic        30 metres  Call to view    4.jpg
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (4473, 22)

# %%
df['brand'].value_counts().plot.bar()
plt.show()

# %%
df['series'].value_counts().iloc[:50].plot.bar()
plt.show()

# %%
df['model'].value_counts().iloc[:50].plot.bar()
plt.show()

# %%
# Inspect missing Values
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
print(f"Rolex: {df['brand'].value_counts()[0]}\nRest: {len(df) - df['brand'].value_counts()[0]}")
# Out:
# Rolex: 794
# Rest: 3679
